# %% [markdown]
# ### Curriculum Modeling: Resident Evaluation
#
# In this notebook, we conduct the performance evaluation for the residentss trained with both interleaved and blocked (control) training schedules.
#
# Taining effect, both overall and by training condition (interleaved vs blocked), on accuracy, sensitivity, and specificity was assessed using mixed effects log binomial regression models. Accuracy, sensitivity, and specificity for each training condition were calculated using marginal means estimations and a comparison between pre- and post-test performance was assessed using Wald tests.
#
# In this notebook, we will use the package lme4 to create our mixed effects regression models, and the package emmeans for marginal mean estimations.
#
# To get started, we load the required packages:

# %%
require(reshape2)
require(lme4)
require(compiler)
require(parallel)
require(boot)
require(lattice)
require(dplyr)

# %%
sessionInfo()
# Out:
# R version 3.6.1 (2019-07-05)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 19044)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=English_United States.1252
# [2] LC_CTYPE=English_United States.1252
# [3] LC_MONETARY=English_United States.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.1252
#
# attached base packages:
# [1] parallel  compiler  stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] forcats_0.4.0   stringr_1.4.0   dplyr_0.8.0.1   purrr_0.3.2
#  [5] readr_1.3.1     tidyr_0.8.3     tibble_2.1.1    ggplot2_3.1.1
#  [9] tidyverse_1.2.1 emmeans_1.3.4   magrittr_1.5    lattice_0.20-38
# [13] boot_1.3-20     lme4_1.1-26     Matrix_1.2-17   reshape2_1.4.3
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.1       lubridate_1.7.4  mvtnorm_1.0-10   assertthat_0.2.1
#  [5] digest_0.6.18    IRdisplay_0.7.0  R6_2.4.0         cellranger_1.1.0
#  [9] plyr_1.8.4       repr_0.19.2      backports_1.1.4  evaluate_0.17
# [13] httr_1.4.0       pillar_1.3.1     rlang_0.3.4      lazyeval_0.2.2
# [17] uuid_0.1-2       readxl_1.3.1     rstudioapi_0.10  minqa_1.2.4
# [21] nloptr_1.2.2.2   splines_3.6.1    statmod_1.4.36   munsell_0.5.0
# [25] broom_0.5.2      modelr_0.1.4     pkgconfig_2.0.2  base64enc_0.1-3
# [29] htmltools_0.3.6  tidyselect_0.2.5 withr_2.1.2      crayon_1.5.2
# [33] MASS_7.3-54      grid_3.6.1       nlme_3.1-152     jsonlite_1.6
# [37] xtable_1.8-4     gtable_0.3.0     scales_1.0.0     cli_1.1.0
# [41] estimability_1.3 stringi_1.4.3    xml2_1.2.0       generics_0.0.2
# [45] IRkernel_0.8.15  tools_3.6.1      glue_1.3.1       hms_0.4.2
# [49] colorspace_1.4-1 rvest_0.3.3      pbdZMQ_0.3-3     haven_2.1.0

# %%
#load the radiology resident results
data <- read.csv('../all_participant_data.csv',na.strings=c(""," "))
data
# Out:
#      ID      trainingLevel stage    viewerInch viewerPix totalTimeMin trialNum
# 1    charlie  1            PreTest  12.166667  1168      41.66643     21
# 2    charlie  1            PreTest  12.166667  1168      41.66643     34
# 3    hotel   NA            PostTest  8.791667   844      17.61012     32
# 4    hotel    1            PreTest   8.791667   844      26.34228     31
# 5    yankee  NA            PostTest 15.718750  1509      19.81012     11
# 6    charlie  1            PreTest  12.166667  1168      41.66643      9
# 7    hotel    1            PreTest   8.791667   844      26.34228     10
# 8    yankee  NA            PostTest 15.718750  1509      19.81012     29
# 9    charlie  1            PreTest  12.166667  1168      41.66643     13
# 10   charlie  1            PreTest  12.166667  1168      41.66643     35
# 11   charlie  1            PreTest  12.166667  1168      41.66643     29
# 12   hotel   NA            PostTest  8.791667   844      17.61012      4
# 13   yankee  NA            PostTest 15.718750  1509      19.81012     35
# 14   charlie NA            PostTest 12.166667  1168      27.54122      8
# 15   hotel   NA            PostTest  8.791667   844      17.61012     22
# 16   yankee   3            PreTest   7.614583   731      28.80967      2
# 17   yankee   3            PreTest   7.614583   731      28.80967     10
# 18   charlie  1            PreTest  12.166667  1168      41.66643     11
# 19   charlie NA            PostTest 12.166667  1168      27.54122     20
# 20   charlie NA            PostTest 12.166667  1168      27.54122     13
# 21   foxtrot  1            PreTest   7.697917   739      26.57342     16
# 22   hotel    1            PreTest   8.791667   844      26.34228      6
# 23   charlie NA            PostTest 12.166667  1168      27.54122     25
# 24   foxtrot  1            PreTest   7.697917   739      26.57342     38
# 25   charlie  1            PreTest  12.166667  1168      41.66643     23
# 26   foxtrot NA            PostTest  7.697917   739      23.75995     17
# 27   charlie  1            PreTest  12.166667  1168      41.66643     15
# 28   charlie  1            PreTest  12.166667  1168      41.66643     31
# 29   mike    NA            PostTest  5.458333   524       5.87750     14
# 30   charlie NA            PostTest 12.166667  1168      27.54122      2
# ...  ...     ...           ...      ...        ...       ...          ...
# 1247 victor  NA            PostTest 9.093750   873        8.394683    20
# 1248 mike    NA            PostTest 5.458333   524        5.877500     5
# 1249 mike     1            PreTest  5.458333   524       49.730833    33
# 1250 victor  NA            PostTest 9.093750   873        8.394683    15
# 1251 echo     1            PreTest  9.916667   952       10.950900    21
# 1252 echo    NA            PostTest 9.916667   952        8.639617    18
# 1253 zulu     3            PreTest  9.510417   913        7.904050    38
# 1254 zulu    NA            PostTest 9.510417   913       91.337550    36
# 1255 quebec  NA            PostTest 6.864583   659        5.092850    31
# 1256 victor  NA            PostTest 9.093750   873        8.394683    26
# 1257 victor  NA            PostTest 9.093750   873        8.394683    16
# 1258 zulu    NA            PostTest 9.510417   913       91.337550    30
# 1259 quebec  NA            PostTest 6.864583   659        5.092850    10
# 1260 quebec  NA            PostTest 6.864583   659        5.092850    27
# 1261 mike    NA            PostTest 5.458333   524        5.877500     7
# 1262 echo     1            PreTest  9.916667   952       10.950900    22
# 1263 echo    NA            PostTest 9.916667   952        8.639617    39
# 1264 victor   2            PreTest  9.093750   873       17.979267    33
# 1265 echo    NA            PostTest 9.916667   952        8.639617     3
# 1266 echo    NA            PostTest 9.916667   952        8.639617    40
# 1267 zulu    NA            PostTest 9.510417   913       91.337550    13
# 1268 victor  NA            PostTest 9.093750   873        8.394683    28
# 1269 zulu    NA            PostTest 9.510417   913       91.337550    20
# 1270 echo    NA            PostTest 9.916667   952        8.639617    32
# 1271 zulu    NA            PostTest 9.510417   913       91.337550    29
# 1272 zulu    NA            PostTest 9.510417   913       91.337550    25
# 1273 victor  NA            PostTest 9.093750   873        8.394683    34
# 1274 victor  NA            PostTest 9.093750   873        8.394683    12
# 1275 victor  NA            PostTest 9.093750   873        8.394683    33
# 1276 zulu    NA            PostTest 9.510417   913       91.337550    26
#      trialOrder caseID             caseType ... LocX LocY clickX clickY
# 1    pTrial11   JPCLN059           Chest    ...  565 1671   NA     NA
# 2    pTrial15   JPCLN051           Chest    ...  524 1462  505   1468
# 3    pTrial28   P_01719            Mammo    ... 1526 1139 1549   1182
# 4    pTrial10   JPCLN072           Chest    ...  401 1270  585    927
# 5    pTrial3    JPCNN008           Chest    ...   NA   NA   NA     NA
# 6    pTrial14   JPCLN052           Chest    ...  836 1167  851   1163
# 7    pTrial20   JPCLN014           Chest    ...  569 1331  556   1301
# 8    pTrial14   JPCLN057           Chest    ...  524 1343  537    763
# 9    pTrial1    JPCNN005           Chest    ...   NA   NA   NA     NA
# 10   pTrial13   JPCLN053           Chest    ...  573 1528  874    946
# 11   pTrial4    JPCNN002           Chest    ...   NA   NA  774   1007
# 12   pTrial39   P_00068            Mammo    ... 1257 1587 1257   1585
# 13   pTrial35   P_00661            Mammo    ...  748  408   NA     NA
# 14   pTrial21   D_4597_1.LEFT_MLO  Mammo    ...   NA   NA  686   1268
# 15   pTrial1    JPCNN010           Chest    ...   NA   NA   NA     NA
# 16   pTrial8    JPCLN076           Chest    ...  332  684  384   1247
# 17   pTrial13   JPCLN053           Chest    ...  573 1528  572   1513
# 18   pTrial16   JPCLN028           Chest    ... 1499  963  653    467
# 19   pTrial14   JPCLN057           Chest    ...  524 1343   NA     NA
# 20   pTrial13   JPCLN063           Chest    ...  466 1236  409   1251
# 21   pTrial18   JPCLN016           Chest    ...  619 1401 1381   1062
# 22   pTrial31   P_01357            Mammo    ...  610 1708  678    998
# 23   pTrial4    JPCNN007           Chest    ...   NA   NA   NA     NA
# 24   pTrial13   JPCLN053           Chest    ...  573 1528 1367   1101
# 25   pTrial10   JPCLN072           Chest    ...  401 1270  746    693
# 26   pTrial10   JPCLN069           Chest    ...  410 1008  408   1020
# 27   pTrial36   D_4553_1.RIGHT_MLO Mammo    ...   NA   NA 1005   1053
# 28   pTrial18   JPCLN016           Chest    ...  619 1401 1536    914
# 29   pTrial15   JPCLN054           Chest    ...  533 1302   NA     NA
# 30   pTrial6    JPCLN128           Chest    ...  614  672  639    679
# ...  ...        ...                ...          ...  ...  ...    ...
# 1247 pTrial40   P_00015            Mammo    ...  550 1149  556   1134
# 1248 pTrial18   JPCLN021           Chest    ... 1577 1302 1583   1286
# 1249 pTrial19   JPCLN015           Chest    ...  549 1053  559   1036
# 1250 pTrial8    JPCLN081           Chest    ... 1446 1216 1448   1197
# 1251 pTrial30   P_01232            Mammo    ... 1267 1004 1272    964
# 1252 pTrial18   JPCLN021           Chest    ... 1577 1302 1603   1302
# 1253 pTrial33   P_01636            Mammo    ...  876  775  869    765
# 1254 pTrial18   JPCLN021           Chest    ... 1577 1302 1584   1311
# 1255 pTrial29   P_01636            Mammo    ...  876  775  868    768
# 1256 pTrial23   D_4542_1.LEFT_MLO  Mammo    ...   NA   NA 1310   1298
# 1257 pTrial29   P_01636            Mammo    ...  876  775  885    770
# 1258 pTrial37   P_00383            Mammo    ...  799  950  788    972
# 1259 pTrial20   JPCLN019           Chest    ...  393 1155  392   1126
# 1260 pTrial23   D_4542_1.LEFT_MLO  Mammo    ...   NA   NA 1303   1287
# 1261 pTrial16   JPCLN045           Chest    ...  680 1782  688   1771
# 1262 pTrial26   P_00396            Mammo    ... 1503  748   NA     NA
# 1263 pTrial29   P_01636            Mammo    ...  876  775  861    753
# 1264 pTrial33   P_01636            Mammo    ...  876  775  887    754
# 1265 pTrial33   P_011151           Mammo    ... 1247  954 1233    932
# 1266 pTrial34   P_00702            Mammo    ...  846  762  863    756
# 1267 pTrial39   P_00068            Mammo    ... 1257 1587 1268   1571
# 1268 pTrial20   JPCLN019           Chest    ...  393 1155  395   1143
# 1269 pTrial32   P_01206            Mammo    ... 1045 1021 1064   1048
# 1270 pTrial23   D_4542_1.LEFT_MLO  Mammo    ...   NA   NA 1304   1317
# 1271 pTrial25   D_4537_1.RIGHT_MLO Mammo    ...   NA   NA  904   1046
# 1272 pTrial34   P_00702            Mammo    ...  846  762  833    750
# 1273 pTrial2    JPCNN009           Chest    ...   NA   NA  693    617
# 1274 pTrial33   P_011151           Mammo    ... 1247  954 1244    955
# 1275 pTrial39   P_00068            Mammo    ... 1257 1587 1227   1577
# 1276 pTrial26   P_01890            Mammo    ... 1280  745 1263    750
#      clickTimeSecs trialTimeSecs response responseType      correct Condition
# 1         NA       194.100       Absent   Miss              No      NonBlocked
# 2    178.328       180.578       Present  Hit               Yes     NonBlocked
# 3    175.875       176.732       Present  Hit               Yes     NonBlocked
# 4    118.409       173.575       Present  Wrong Location    No      NonBlocked
# 5         NA       170.773       Absent   Correct Rejection Yes     Blocked
# 6    158.540       161.009       Present  Hit               Yes     NonBlocked
# 7    158.129       159.411       Present  Hit               Yes     NonBlocked
# 8    150.129       154.190       Present  Wrong Location    No      Blocked
# 9         NA       144.260       Absent   Correct Rejection Yes     NonBlocked
# 10   136.768       139.709       Present  Wrong Location    No      NonBlocked
# 11   128.924       131.259       Present  False Alarm       No      NonBlocked
# 12   125.753       127.461       Present  Hit               Yes     NonBlocked
# 13        NA       118.412       Absent   Miss              No      Blocked
# 14   113.822       117.414       Present  False Alarm       No      NonBlocked
# 15        NA       117.048       Absent   Correct Rejection Yes     NonBlocked
# 16   106.905       113.665       Present  Wrong Location    No      Blocked
# 17   107.453       112.563       Present  Hit               Yes     Blocked
# 18   104.261       108.076       Present  Wrong Location    No      NonBlocked
# 19        NA       106.066       Absent   Miss              No      NonBlocked
# 20   100.885       103.578       Present  Hit               Yes     NonBlocked
# 21    95.036        97.288       Present  Wrong Location    No      NonBlocked
# 22    49.354        97.032       Present  Wrong Location    No      NonBlocked
# 23        NA        93.644       Absent   Correct Rejection Yes     NonBlocked
# 24    89.885        91.553       Present  Wrong Location    No      NonBlocked
# 25    84.884        90.630       Present  Wrong Location    No      NonBlocked
# 26    88.401        90.417       Present  Hit               Yes     NonBlocked
# 27    88.486        90.239       Present  False Alarm       No      NonBlocked
# 28    75.930        89.522       Present  Wrong Location    No      NonBlocked
# 29        NA        87.707       Absent   Miss              No      Blocked
# 30    69.172        87.161       Present  Hit               Yes     NonBlocked
# ...  ...           ...           ...      ...               ...     ...
# 1247 1.804         2.501         Present  Hit               Yes     Blocked
# 1248 1.762         2.496         Present  Hit               Yes     Blocked
# 1249 1.502         2.495         Present  Hit               Yes     Blocked
# 1250 1.275         2.431         Present  Hit               Yes     Blocked
# 1251 1.711         2.422         Present  Hit               Yes     Blocked
# 1252 1.687         2.415         Present  Hit               Yes     Blocked
# 1253 1.455         2.376         Present  Hit               Yes     NonBlocked
# 1254 1.446         2.350         Present  Hit               Yes     NonBlocked
# 1255 1.278         2.343         Present  Hit               Yes     Blocked
# 1256 1.540         2.340         Present  False Alarm       No      Blocked
# 1257 1.510         2.320         Present  Hit               Yes     Blocked
# 1258 1.476         2.307         Present  Hit               Yes     NonBlocked
# 1259 1.395         2.287         Present  Hit               Yes     Blocked
# 1260 1.372         2.260         Present  False Alarm       No      Blocked
# 1261 1.532         2.252         Present  Hit               Yes     Blocked
# 1262    NA         2.231         Absent   Miss              No      Blocked
# 1263 1.385         2.223         Present  Hit               Yes     Blocked
# 1264 1.216         2.219         Present  Hit               Yes     Blocked
# 1265 1.416         2.207         Present  Hit               Yes     Blocked
# 1266 1.305         2.167         Present  Hit               Yes     Blocked
# 1267 1.250         2.160         Present  Hit               Yes     NonBlocked
# 1268 1.320         2.146         Present  Hit               Yes     Blocked
# 1269 1.135         2.125         Present  Hit               Yes     NonBlocked
# 1270 1.341         2.109         Present  False Alarm       No      Blocked
# 1271 1.155         2.063         Present  False Alarm       No      NonBlocked
# 1272 1.286         2.032         Present  Hit               Yes     NonBlocked
# 1273 1.239         2.015         Present  False Alarm       No      Blocked
# 1274 1.270         1.986         Present  Hit               Yes     Blocked
# 1275 1.267         1.849         Present  Hit               Yes     Blocked
# 1276 1.002         1.774         Present  Hit               Yes     NonBlocked

# %% [markdown]
# #### 1.0 Mixed Effects Log Binomial Model
#
# In the following cells, we create a mixed effects log-binomial regression model of the form Correct ~ Time * Condition * Abnormality. The fold is added as a random effect.

# %%
data$stage <- factor(data$stage, levels = c('PreTest', 'PostTest'))
data$abnormality <- factor(data$abnormality, levels = c('Yes', 'No'))

# %%
### Use full model for marginal means estimation though it was not the best model.
fm=as.formula (correct ~ stage+ Condition + abnormality + stage:abnormality+stage:Condition + Condition:abnormality + stage:Condition:abnormality + (1|ID))
fit=glmer(fm, family=binomial(log), control=glmerControl(optimizer="bobyqa"), data=data);
summary(fit)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( log )
# Formula: correct ~ stage + Condition + abnormality + stage:abnormality +
#     stage:Condition + Condition:abnormality + stage:Condition:abnormality +
#     (1 | ID)
#    Data: data
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   1732.1   1778.4   -857.0   1714.1     1267
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4697 -0.9356  0.6975  0.8998  1.3919
#
# Random effects:
#  Groups Name        Variance Std.Dev.
#  ID     (Intercept) 0.008525 0.09233
# Number of obs: 1276, groups:  ID, 16
#
# Fixed effects:
#                                                 Estimate Std. Error z value
# (Intercept)                                     -0.82830    0.08032 -10.312
# stagePostTest                                    0.36781    0.08816   4.172
# ConditionNonBlocked                             -0.14239    0.11955  -1.191
# abnormalityNo                                    0.31843    0.11691   2.724
# stagePostTest:abnormalityNo                     -0.57860    0.17023  -3.399
# stagePostTest:ConditionNonBlocked                0.10536    0.13101   0.804
# ConditionNonBlocked:abnormalityNo               -0.03738    0.18118  -0.206
# stagePostTest:ConditionNonBlocked:abnormalityNo  0.19468    0.24683   0.789
#                                                 Pr(>|z|)
# (Intercept)                                      < 2e-16 ***
# stagePostTest                                   3.02e-05 ***
# ConditionNonBlocked                             0.233650
# abnormalityNo                                   0.006457 **
# stagePostTest:abnormalityNo                     0.000677 ***
# stagePostTest:ConditionNonBlocked               0.421259
# ConditionNonBlocked:abnormalityNo               0.836533
# stagePostTest:ConditionNonBlocked:abnormalityNo 0.430261
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) stgPsT CndtNB abnrmN stPT:N stPT:CNB CnNB:N
# stagePstTst -0.759
# CndtnNnBlck -0.672  0.511
# abnormaltyN -0.577  0.527  0.389
# stgPstTst:N  0.395 -0.522 -0.266 -0.682
# stgPstT:CNB  0.511 -0.672 -0.776 -0.353  0.350
# CndtnNnBl:N  0.372 -0.340 -0.564 -0.646  0.441  0.514
# stgPT:CNB:N -0.272  0.360  0.414  0.471 -0.690 -0.533   -0.733

# %%
se <- sqrt(diag(vcov(fit)))

# table of estimates with 95% CI
tab <- cbind(Est = fixef(fit), LL = fixef(fit) - 1.96 * se, UL = fixef(fit) + 1.96 *
    se)

# calculate risk ratios by taking the exponential 
exp(tab)
# Out:
#                                                 Est       LL        UL
# (Intercept)                                     0.4367902 0.3731635 0.5112656
# stagePostTest                                   1.4445701 1.2153387 1.7170381
# ConditionNonBlocked                             0.8672832 0.6861113 1.0962946
# abnormalityNo                                   1.3749637 1.0933843 1.7290584
# stagePostTest:abnormalityNo                     0.5606811 0.4016157 0.7827465
# stagePostTest:ConditionNonBlocked               1.1111139 0.8594903 1.4364027
# ConditionNonBlocked:abnormalityNo               0.9633080 0.6753750 1.3739957
# stagePostTest:ConditionNonBlocked:abnormalityNo 1.2149278 0.7489379 1.9708572

# %%
# Calculate estimates and confidence intervals
ci <- confint(fit, method='Wald')[-1,]
est <- fixef(fit)
exp_est <- exp(est)
exp_ci <- exp(ci)

# Get p-values
p <- summary(fit)$coefficients[,4]

# Combine results into one dataframe
results <- data.frame(RR = exp_est,
                      ci_low = exp_ci[,1],
                      ci_high = exp_ci[,2],
                      p_value = p)

# Print results
results
# Out:
#                                                 RR        ci_low    ci_high
# (Intercept)                                     0.4367902 0.3731646 0.5112641
# stagePostTest                                   1.4445701 1.2153426 1.7170326
# ConditionNonBlocked                             0.8672832 0.6861142 1.0962899
# abnormalityNo                                   1.3749637 1.0933889 1.7290512
# stagePostTest:abnormalityNo                     0.5606811 0.4016182 0.7827417
# stagePostTest:ConditionNonBlocked               1.1111139 0.8594943 1.4363959
# ConditionNonBlocked:abnormalityNo               0.9633080 0.6753794 1.3739868
# stagePostTest:ConditionNonBlocked:abnormalityNo 1.2149278 0.7489445 1.9708397
#                                                 p_value
# (Intercept)                                     6.223547e-25
# stagePostTest                                   3.016656e-05
# ConditionNonBlocked                             2.336502e-01
# abnormalityNo                                   6.456983e-03
# stagePostTest:abnormalityNo                     6.765996e-04
# stagePostTest:ConditionNonBlocked               4.212590e-01
# ConditionNonBlocked:abnormalityNo               8.365331e-01
# stagePostTest:ConditionNonBlocked:abnormalityNo 4.302613e-01

# %%
library(emmeans)

# Calculate the EMMs and pairwise comparisons
emm.1 <- emmeans(fit, ~ stage)
pairwise <- as.data.frame(pairs(regrid(emm.1), transform = "log"))

# print the EMM - corresponding to Pre and Post-test accuracy in this case
summary(emm.1, type="response")

# Print the p.value
pairwise
# Out:
# NOTE: Results may be misleading due to involvement in interactions
#   stage    prob      SE         df  asymp.LCL asymp.UCL
# 1 PreTest  0.4725418 0.02399422 Inf 0.4277784 0.5219894
# 2 PostTest 0.5656577 0.02717626 Inf 0.5148241 0.6215106
#   contrast           estimate    SE         df  z.ratio   p.value
# 1 PreTest - PostTest -0.09311593 0.03193585 Inf -2.915718 0.003548714

# %%
# Calculate the EMMs and pairwise comparisons
emm.1 <- emmeans(fit, ~ Condition * stage)
pairwise <- as.data.frame(pairs(regrid(emm.1), transform = "log"))

# print the EMM - corresponding to Pre and Post-test accuracy by training schedule
summary(emm.1, type="response")

# Print the p.value
pairwise
# Out:
# NOTE: Results may be misleading due to involvement in interactions
#   Condition  stage    prob      SE         df  asymp.LCL asymp.UCL
# 1 Blocked    PreTest  0.5121751 0.03417838 Inf 0.4493826 0.5837417
# 2 NonBlocked PreTest  0.4359754 0.03332726 Inf 0.3753130 0.5064428
# 3 Blocked    PostTest 0.5540068 0.03888580 Inf 0.4828021 0.6357129
# 4 NonBlocked PostTest 0.5775537 0.03773274 Inf 0.5081380 0.6564522
#   contrast                                 estimate    SE         df
# 1 Blocked,PreTest - NonBlocked,PreTest      0.07619973 0.04769884 Inf
# 2 Blocked,PreTest - Blocked,PostTest       -0.04183164 0.04537390 Inf
# 3 Blocked,PreTest - NonBlocked,PostTest    -0.06537859 0.05079472 Inf
# 4 NonBlocked,PreTest - Blocked,PostTest    -0.11803137 0.05117649 Inf
# 5 NonBlocked,PreTest - NonBlocked,PostTest -0.14157832 0.04461772 Inf
# 6 Blocked,PostTest - NonBlocked,PostTest   -0.02354695 0.05407176 Inf
#   z.ratio    p.value
# 1  1.5975177 0.379987663
# 2 -0.9219317 0.793121770
# 3 -1.2871137 0.571147763
# 4 -2.3063591 0.096539870
# 5 -3.1731414 0.008212939
# 6 -0.4354760 0.972359305

# %%
# Calculate the EMMs and pairwise comparisons
emm.1 <- emmeans(fit, ~ Condition * stage * abnormality)
pairwise <- as.data.frame(pairs(regrid(emm.1), transform = "log"))

# print the EMM - corresponding to Pre and Post-test sensitivity (abnormality YES) and specificity (abnormality NO)
# by training schedule (blocked vs non-blocked)
summary(emm.1, type="response")

# Print the p.value
pairwise
# Out:
#   Condition  stage    abnormality prob      SE         df  asymp.LCL asymp.UCL
# 1 Blocked    PreTest  Yes         0.4367902 0.03508501 Inf 0.3731646 0.5112641
# 2 NonBlocked PreTest  Yes         0.3788208 0.03354713 Inf 0.3184595 0.4506230
# 3 Blocked    PostTest Yes         0.6309740 0.03716962 Inf 0.5621713 0.7081974
# 4 NonBlocked PostTest Yes         0.6080384 0.03715284 Inf 0.5394115 0.6853963
# 5 Blocked    PreTest  No          0.6005707 0.05788131 Inf 0.4971961 0.7254384
# 6 NonBlocked PreTest  No          0.5017533 0.05811052 Inf 0.3998604 0.6296106
# 7 Blocked    PostTest No          0.4864281 0.05781083 Inf 0.3853500 0.6140192
# 8 NonBlocked PostTest No          0.5485975 0.05797663 Inf 0.4459616 0.6748544
#    contrast                                         estimate     SE         df
# 1  Blocked,PreTest,Yes - NonBlocked,PreTest,Yes      0.057969416 0.04854039 Inf
# 2  Blocked,PreTest,Yes - Blocked,PostTest,Yes       -0.194183862 0.04494289 Inf
# 3  Blocked,PreTest,Yes - NonBlocked,PostTest,Yes    -0.171248190 0.05109523 Inf
# 4  Blocked,PreTest,Yes - Blocked,PreTest,No         -0.163780483 0.06354279 Inf
# 5  Blocked,PreTest,Yes - NonBlocked,PreTest,No      -0.064963071 0.06787983 Inf
# 6  Blocked,PreTest,Yes - Blocked,PostTest,No        -0.049637914 0.06421906 Inf
# 7  Blocked,PreTest,Yes - NonBlocked,PostTest,No     -0.111807271 0.06776236 Inf
# 8  NonBlocked,PreTest,Yes - Blocked,PostTest,Yes    -0.252153278 0.05000947 Inf
# 9  NonBlocked,PreTest,Yes - NonBlocked,PostTest,Yes -0.229217606 0.04480401 Inf
# 10 NonBlocked,PreTest,Yes - Blocked,PreTest,No      -0.221749899 0.06682851 Inf
# 11 NonBlocked,PreTest,Yes - NonBlocked,PreTest,No   -0.122932487 0.06402753 Inf
# 12 NonBlocked,PreTest,Yes - Blocked,PostTest,No     -0.107607330 0.06681748 Inf
# 13 NonBlocked,PreTest,Yes - NonBlocked,PostTest,No  -0.169776687 0.06352058 Inf
# 14 Blocked,PostTest,Yes - NonBlocked,PostTest,Yes    0.022935672 0.05238285 Inf
# 15 Blocked,PostTest,Yes - Blocked,PreTest,No         0.030403379 0.06249271 Inf
# 16 Blocked,PostTest,Yes - NonBlocked,PreTest,No      0.129220791 0.06895098 Inf
# 17 Blocked,PostTest,Yes - Blocked,PostTest,No        0.144545948 0.06384009 Inf
# 18 Blocked,PostTest,Yes - NonBlocked,PostTest,No     0.082376591 0.06875223 Inf
# 19 NonBlocked,PostTest,Yes - Blocked,PreTest,No      0.007467707 0.06857119 Inf
# 20 NonBlocked,PostTest,Yes - NonBlocked,PreTest,No   0.106285119 0.06398886 Inf
# 21 NonBlocked,PostTest,Yes - Blocked,PostTest,No     0.121610277 0.06865675 Inf
# 22 NonBlocked,PostTest,Yes - NonBlocked,PostTest,No  0.059440919 0.06338349 Inf
# 23 Blocked,PreTest,No - NonBlocked,PreTest,No        0.098817412 0.08197812 Inf
# 24 Blocked,PreTest,No - Blocked,PostTest,No          0.114142569 0.07756061 Inf
# 25 Blocked,PreTest,No - NonBlocked,PostTest,No       0.051973212 0.08176841 Inf
# 26 NonBlocked,PreTest,No - Blocked,PostTest,No       0.015325157 0.08195681 Inf
# 27 NonBlocked,PreTest,No - NonBlocked,PostTest,No   -0.046844200 0.07843717 Inf
# 28 Blocked,PostTest,No - NonBlocked,PostTest,No     -0.062169357 0.08182685 Inf
#    z.ratio    p.value
# 1   1.1942511 9.338423e-01
# 2  -4.3206807 4.135847e-04
# 3  -3.3515494 1.827882e-02
# 4  -2.5774834 1.640652e-01
# 5  -0.9570306 9.802002e-01
# 6  -0.7729467 9.944655e-01
# 7  -1.6499909 7.195960e-01
# 8  -5.0421107 1.269652e-05
# 9  -5.1160063 8.622155e-06
# 10 -3.3181932 2.041960e-02
# 11 -1.9199941 5.369661e-01
# 12 -1.6104668 7.441885e-01
# 13 -2.6727825 1.309004e-01
# 14  0.4378470 9.998618e-01
# 15  0.4865108 9.997202e-01
# 16  1.8740964 5.688630e-01
# 17  2.2641878 3.135897e-01
# 18  1.1981661 9.327271e-01
# 19  0.1089045 1.000000e+00
# 20  1.6609942 7.126036e-01
# 21  1.7712792 6.397106e-01
# 22  0.9377982 9.823880e-01
# 23  1.2054121 9.306298e-01
# 24  1.4716564 8.227365e-01
# 25  0.6356148 9.983870e-01
# 26  0.1869907 9.999996e-01
# 27 -0.5972194 9.989215e-01
# 28 -0.7597672 9.950232e-01

# %% [markdown]
# #### 2.0 Comparison between radiology residents and the machine learners
#
# Here we will make a mixed effects model that compares the residents to the machine learning algorithms.

# %%
hdata <- read.csv('../all_participant_data.csv',na.strings=c(""," "))
mdata <- read.csv('../reports/cnn_results.csv',na.strings=c(""," "))

# %%
#format columns
hdata$Correct = hdata$correct
hdata$Condition = tolower(hdata$Condition)
hdata$stage <- gsub("PreTest", "Pre", as.character(hdata$stage))
hdata$stage <- gsub("PostTest", "Post", as.character(hdata$stage))
hdata$Time <- hdata$stage
hdata$Abnormality <- hdata$abnormality
hdata = hdata %>% select("Condition", "Time", "Abnormality", "Correct", "ID")
mdata$ID = mdata$Fold
mdata = mdata %>% select("Condition", "Time", "Abnormality", "Correct", "ID")

# define learners
mdata$Learner = "Machine"
hdata$Learner = "Human"

# %%
# combine dataframes!
df <- rbind.data.frame(mdata,hdata)

# %%
df$Time <- factor(df$Time, levels = c('Pre', 'Post'))
df$Learner <- factor(df$Learner, levels = c("Machine", "Human"))
df$Abnormality <- factor(df$Abnormality, levels = c("Yes", "No"))
# Replace "Yes" with 1 and "No" with 0
df$Correct <- ifelse(df$Correct == "Yes", 1, 0)

# %%
# print the dataframe to ensure it was correctly formatted
df <- subset(df, Time == "Post")
df <- subset(df, Condition == "nonblocked")
df
# Out:
#      Condition  Time Abnormality Correct ID      Learner
# 1    nonblocked Post Yes         1       fold_0  Machine
# 2    nonblocked Post Yes         1       fold_0  Machine
# 3    nonblocked Post No          1       fold_0  Machine
# 4    nonblocked Post No          0       fold_0  Machine
# 5    nonblocked Post Yes         0       fold_0  Machine
# 6    nonblocked Post Yes         1       fold_0  Machine
# 7    nonblocked Post No          0       fold_0  Machine
# 8    nonblocked Post Yes         1       fold_0  Machine
# 9    nonblocked Post Yes         1       fold_0  Machine
# 10   nonblocked Post No          0       fold_0  Machine
# 11   nonblocked Post Yes         1       fold_0  Machine
# 12   nonblocked Post Yes         0       fold_0  Machine
# 13   nonblocked Post Yes         0       fold_0  Machine
# 14   nonblocked Post Yes         0       fold_0  Machine
# 15   nonblocked Post Yes         1       fold_0  Machine
# 16   nonblocked Post Yes         1       fold_0  Machine
# 17   nonblocked Post Yes         0       fold_0  Machine
# 18   nonblocked Post No          1       fold_0  Machine
# 19   nonblocked Post Yes         0       fold_0  Machine
# 20   nonblocked Post No          1       fold_0  Machine
# 21   nonblocked Post Yes         0       fold_0  Machine
# 22   nonblocked Post No          0       fold_0  Machine
# 23   nonblocked Post No          1       fold_0  Machine
# 24   nonblocked Post Yes         0       fold_0  Machine
# 25   nonblocked Post Yes         1       fold_0  Machine
# 26   nonblocked Post Yes         1       fold_0  Machine
# 27   nonblocked Post Yes         1       fold_0  Machine
# 28   nonblocked Post Yes         1       fold_0  Machine
# 29   nonblocked Post Yes         0       fold_0  Machine
# 30   nonblocked Post Yes         0       fold_0  Machine
# ...  ...        ...  ...         ...     ...     ...
# 1965 nonblocked Post Yes         1       hotel   Human
# 1972 nonblocked Post Yes         1       hotel   Human
# 1974 nonblocked Post Yes         1       zulu    Human
# 1986 nonblocked Post Yes         1       whiskey Human
# 1989 nonblocked Post Yes         1       whiskey Human
# 1991 nonblocked Post Yes         1       lima    Human
# 1992 nonblocked Post Yes         1       whiskey Human
# 1994 nonblocked Post Yes         1       zulu    Human
# 2000 nonblocked Post Yes         1       whiskey Human
# 2002 nonblocked Post No          0       zulu    Human
# 2003 nonblocked Post No          0       whiskey Human
# 2004 nonblocked Post Yes         1       bravo   Human
# 2012 nonblocked Post Yes         1       hotel   Human
# 2015 nonblocked Post Yes         1       zulu    Human
# 2016 nonblocked Post Yes         1       zulu    Human
# 2021 nonblocked Post Yes         1       zulu    Human
# 2022 nonblocked Post Yes         1       zulu    Human
# 2023 nonblocked Post Yes         1       zulu    Human
# 2025 nonblocked Post No          0       lima    Human
# 2037 nonblocked Post Yes         1       zulu    Human
# 2040 nonblocked Post Yes         1       zulu    Human
# 2043 nonblocked Post No          0       zulu    Human
# 2044 nonblocked Post Yes         1       whiskey Human
# 2053 nonblocked Post Yes         1       zulu    Human
# 2057 nonblocked Post Yes         1       zulu    Human
# 2066 nonblocked Post Yes         1       zulu    Human
# 2068 nonblocked Post Yes         1       zulu    Human
# 2070 nonblocked Post No          0       zulu    Human
# 2071 nonblocked Post Yes         1       zulu    Human
# 2075 nonblocked Post Yes         1       zulu    Human

# %%
fm=as.formula (Correct ~ Learner + Abnormality * Learner + (1|ID))
m=glmer(fm, family=binomial(log), control=glmerControl(optimizer="bobyqa"), data=df, verbose=0);
summary(m)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( log )
# Formula: Correct ~ Learner + Abnormality * Learner + (1 | ID)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#    694.3    715.6   -342.2    684.3      513
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8746 -1.1585  0.6886  0.7874  0.9974
#
# Random effects:
#  Groups Name        Variance Std.Dev.
#  ID     (Intercept) 0.01115  0.1056
# Number of obs: 518, groups:  ID, 13
#
# Fixed effects:
#                            Estimate Std. Error z value Pr(>|z|)
# (Intercept)                -0.38322    0.07375  -5.196 2.04e-07 ***
# LearnerHuman               -0.11605    0.09775  -1.187    0.235
# AbnormalityNo              -0.17029    0.13218  -1.288    0.198
# LearnerHuman:AbnormalityNo  0.06822    0.17442   0.391    0.696
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) LrnrHm AbnrmN
# LearnerHumn -0.755
# AbnormaltyN -0.336  0.264
# LrnrHmn:AbN  0.255 -0.359 -0.758

# %%
se <- sqrt(diag(vcov(m)))

# table of estimates with 95% CI
tab <- cbind(Est = fixef(m), LL = fixef(m) - 1.96 * se, UL = fixef(m) + 1.96 *
    se)

# calculate risk ratios by taking the exponential 
exp(tab)
# Out:
#                            Est       LL        UL
# (Intercept)                0.6816630 0.5899153 0.7876799
# LearnerHuman               0.8904319 0.7351814 1.0784671
# AbnormalityNo              0.8434195 0.6509288 1.0928329
# LearnerHuman:AbnormalityNo 1.0706025 0.7606107 1.5069335

# %%
# Calculate estimates and confidence intervals
ci <- confint(m, method='Wald')[-1,]
est <- fixef(m)
exp_est <- exp(est)
exp_ci <- exp(ci)

# Get p-values
p <- summary(m)$coefficients[,4]

# Combine results into one dataframe
results <- data.frame(RR = exp_est,
                      ci_low = exp_ci[,1],
                      ci_high = exp_ci[,2],
                      p_value = p)

# Print results
results
# Out:
#                            RR        ci_low    ci_high   p_value
# (Intercept)                0.6816630 0.5899169 0.7876778 2.036539e-07
# LearnerHuman               0.8904319 0.7351840 1.0784633 2.351478e-01
# AbnormalityNo              0.8434195 0.6509319 1.0928277 1.976178e-01
# LearnerHuman:AbnormalityNo 1.0706025 0.7606155 1.5069241 6.956914e-01

# %%
library(emmeans)

# Calculate the EMMs and pairwise comparisons
emm.1 <- emmeans(m, ~ Learner)
pairwise <- as.data.frame(pairs(regrid(emm.1), transform = "log"))

# print the EMM - corresponding to Pre and Post-test accuracy in this case
summary(emm.1, type="response")

# Print the p.value
pairwise
# Out:
# NOTE: Results may be misleading due to involvement in interactions
#   Learner prob      SE         df  asymp.LCL asymp.UCL
# 1 Machine 0.6260248 0.05058533 Inf 0.5343318 0.7334526
# 2 Human   0.5767749 0.03930072 Inf 0.5046689 0.6591833
#   contrast        estimate   SE         df  z.ratio   p.value
# 1 Machine - Human 0.04924985 0.06369623 Inf 0.7731989 0.4394047

# %%
emm.1 <- emmeans(m, ~ Learner * Abnormality)
pairwise <- as.data.frame(pairs(regrid(emm.1), transform = "log"))

# print the EMM - corresponding to Post-test sensitivity (abnormality YES) and specificity (abnormality NO)
# by training schedule (blocked vs non-blocked)
summary(emm.1, type="response")

# Print the p.value
pairwise
# Out:
#   Learner Abnormality prob      SE         df  asymp.LCL asymp.UCL
# 1 Machine Yes         0.6816630 0.05027488 Inf 0.5899169 0.7876778
# 2 Human   Yes         0.6069745 0.03891752 Inf 0.5352957 0.6882514
# 3 Machine No          0.5749279 0.07352389 Inf 0.4474645 0.7387001
# 4 Human   No          0.5480780 0.05912786 Inf 0.4436218 0.6771296
#   contrast                 estimate   SE         df  z.ratio   p.value
# 1 Machine,Yes - Human,Yes  0.07468851 0.06359222 Inf 1.1744912 0.6430044
# 2 Machine,Yes - Machine,No 0.10673514 0.07898707 Inf 1.3512988 0.5301353
# 3 Machine,Yes - Human,No   0.13358504 0.07762205 Inf 1.7209677 0.3126567
# 4 Human,Yes - Machine,No   0.03204663 0.08261716 Inf 0.3878932 0.9801808
# 5 Human,Yes - Human,No     0.05889654 0.06381140 Inf 0.9229783 0.7925564
# 6 Machine,No - Human,No    0.02684990 0.09393305 Inf 0.2858409 0.9918639
